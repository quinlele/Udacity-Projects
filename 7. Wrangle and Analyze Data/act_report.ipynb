# %% [markdown]
#  # Analyzing and visualizing data
#
#  These are some analysis and visualization for my project.
#
#  ## Insight One

# %% [markdown]
# We use this code to get the insight about "Which dog breed has the most favorite count?"
#
# ```df_twit.groupby('dog_breed')['favorite_count'].mean()```

# %% [markdown]
# |Dog breed | Mean of favorite count |
# |----------|------------------------|
# |doggo & puppo|      47844.000000|
# |puppo|              21582.090909|
# |doggo     |         19356.380952|
# |doggo & floofer |   17169.000000|
# |floofer|            13206.000000|
# |doggo & pupper|     12533.111111|
# |none      |         8478.924763|
# |pupper|              7197.738916|

# %% [markdown]
# In the table above, doggo & puppo has the most favorite count in dog breed, following is puppo and then doggo
#
# ## Insight two

# %% [markdown]
# We use this code to get the insight about "Which dog breed has the most twitter count?"
#
# ```df_twit.groupby('dog_breed')['retweet_count'].mean()```

# %% [markdown]
# |Dog breed | Mean of retweet count |
# |----------|------------------------|
# |doggo & puppo|      19196.000000|
# |doggo          |     7125.698413|
# |puppo|               6473.954545|
# |floofer|             4968.714286|
# |doggo & pupper|      4083.444444|
# |doggo & floofer|     3433.000000|
# |none            |        2577.957346|
# |pupper|              2363.581281|

# %% [markdown]
# In the table above, doggo & puppo has the most retweet count in dog breed, following is doggo and then puppo
#
# ## Insight three and visualization

# %% [markdown]
# We use this code to get the insight about "Which is the most popular dog name in this dataset?"
#
# ```df_twit['name'].value_counts()```

# %% [markdown]
# |Name of dogs | Number of name |
# |----------|------------------------|
# | Charlie      |      11|
# |Cooper       |      10|
# |Oliver      |       10|
# |Lucy       |        10|
# |Tucker    |          9|
# |Penny    |           9|
# |Sadie   |            8|
# |Winston|             8|

# %% [markdown]
# In the table above, the most popular dog names in this dataset is Charlie, following is Cooper, Oliver, Lucy

# %% [markdown]
# ![image.png](attachment:image.png)
